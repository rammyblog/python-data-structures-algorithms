# %% [markdown]
# ## Stack Data Structure.
#
# Books on the floor
# A B C D
#
# Stack them on each other
# D
# C
# B
# A
#
# Retrieving the books, you will take from the top to bottom.
# A B C D
#
# Push - Takes to the top of the stack
# Pop - Remove from the top

# %%
class Stack():
    def __init__(self):
        self.items = []
        
    def push(self, item):
        self.items.append(item)
    
    def pop(self):
        return self.items.pop()
    
    def is_empty(self):
        return self.items == []
    
    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        
    
    def get_stack(self):
        return self.items
def is_match(p1, p2):
    if p1 =="{"and p2 == "}":
        return True
    elif p1 =="("and p2 == ")":
        return True
    elif p1 =="["and p2 == "]":
        return True
    else:
        return False

def is_paren_balanced(paren_string):
    is_balanced = True
    index = 0
    s = Stack()
    
    while index < len(paren_string) and is_balanced:
        paren = paren_string[index]
        
        if paren in "[({":
            s.push(paren)
        else:
            if s.is_empty():
                is_balanced = False
            else:
                p1 = s.pop()
                if not is_match(p1, paren):
                    is_balanced = False
    index += 1
    
    if s.is_empty() and is_balanced:
        return True
    else: 
        return False

print(is_paren_balanced("()(()(({[]}))"))
print(is_paren_balanced("()()()(({[]}))"))
print(is_paren_balanced("[]"))

# %%
class Stack():
    def __init__(self):
        self.items = []
        
    def push(self, item):
        self.items.append(item)
    
    def pop(self):
        return self.items.pop()
    
    def is_empty(self):
        return self.items == []
    
    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        
    
    def get_stack(self):
        return self.items

    
s = Stack()
print(s.is_empty())
s.push('A')
s.push('B')
print(s.get_stack())
s.push('C')
print(s.get_stack())
s.pop()
print(s.get_stack())
print(s.is_empty())


# PEEK
# s.push('A')
# s.push('B')
# s.push('C')
# s.push('D')
# print(s.peek())
# Out:
# D

# %%
"""
    Use a stack to check whether or not a string has balanced 
    usage of parenthesis.
    
    Example:
        (), ()(), (({[]})) <- Balanced.
        ((), {{{)}], [][]]] <- Not Balanced
        
    Balanced Example: {[]}
    
    ]
    [
    {
    
    Non-Balanced Example: (()
    
"""



class Stack:
    def __init__(self):
        self.items = []
        
    def push(self, item):
        self.items.append(item)
    
    def pop(self):
        return self.items.pop()
    
    def is_empty(self):
        return self.items == []
    
    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        
    
    def get_stack(self):
        return self.items

def is_match(p1, p2):
    if p1 =="{"and p2 == "}":
        return True
    elif p1 =="("and p2 == ")":
        return True
    elif p1 =="["and p2 == "]":
        return True
    else:
        return False
    
def is_paren_balanced(paren_string):    
    s = Stack()
    is_balanced = True
    index = 0
    
    
    
    while index < len(paren_string) and is_balanced:
        """
            Iterate over the paren_string till is_balanced is false
        """
        paren = paren_string[index]
#         If it is an opening paren, push to the top of the stack
        if paren in "([{":
            s.push(paren)
        else:
#             If it is a closing paren, check if stack is not empty
            if s.is_empty():
                is_balanced = False
#             If stack is not empty, pop the current element at the top of the stack then compare it to the element
#         you are iterating on, 
            else:
                top = s.pop()
                if not is_match(top, paren):
                    is_balanced = False
        index += 1
        
#         Check whether it is balanced or not
    if s.is_empty() and is_balanced:
        return True
    else:
        return False

print(is_paren_balanced("()(()(({[]}))"))
print(is_paren_balanced("()()()(({[]}))"))
print(is_paren_balanced("[]"))
# Out:
# False
# True
# True

# %% [markdown]
# Use a stack DS to convert integer values to binary.
#
# Example: 242
#
# 242/2 = 121 => 0
# 121/2 = 60 => 1
# 60/2 = 30 => 0
# 30/2 = 15 => 0
# 15/2 = 7 => 1
# 7/2 = 3 => 1
# 3/2 = 1 => 1
# 1/2 = 0 => 1
#
# We would the stack to keep track of the remainder.

# %%
class Stack():
    def __init__(self):
        self.items = []
        
    def push(self, item):
        self.items.append(item)
    
    def pop(self):
        return self.items.pop()
    
    def is_empty(self):
        return self.items == []
    
    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        
    
    def get_stack(self):
        return self.items
    
def div_by_two(dec_num):
    s = Stack()
#     While dec_num > 0 
# Not dec_num means Decimal Number (Number in base 10)
    while dec_num > 0:
#         Get the remainder
        remainder = dec_num % 2
#     Push the remainder
        s.push(remainder)
#     Get the integer part of the division by 2
        dec_num = dec_num//2
#     Read the stack from bottom to top
    bin_num = ''
    while not s.is_empty():
        bin_num += str(s.pop())
    return bin_num
print(div_by_two(2))
# Out:
# 10
